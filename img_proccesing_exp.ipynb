# %%
import cv2
import numpy as np

# %%
image = cv2.imread('box_data/rgb_img/rgb_img_0001.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 image = cv2.imread('box_data/rgb_img/rgb_img_0001.png')
# ----> 2 plt.imshow(image)
#       3 plt.show()
#
# NameError: name 'plt' is not defined
